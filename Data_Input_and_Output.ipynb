# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('example')
df

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
# !pip install lxml
# conda install html5lib
# conda install BeautifulSoup4

# %%
# !pip install html5lib

# %%
# !pip install BeautifulSoup4

# %%
#pd.read_excel('Excel.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\doumb\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\doumb\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\doumb\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %%
! pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\doumb\anaconda3\lib\site-packages (4.9.1)

# %%
! pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\users\doumb\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\doumb\anaconda3\lib\site-packages (from BeautifulSoup4) (2.3.1)

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
df = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
df[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# 0                            Equity Bank    October 23, 2020     10538
# 1              United Fidelity Bank, fsb    October 16, 2020     10537
# 2                         MVB Bank, Inc.       April 3, 2020     10536
# 3             Farmers and Merchants Bank   February 14, 2020     10535
# 4                        Industrial Bank    November 1, 2019     10534
# ..                                   ...                 ...       ...
# 558                Superior Federal, FSB       July 27, 2001      6004
# 559                    North Valley Bank         May 3, 2001      4648
# 560  Southern New Hampshire Bank & Trust    February 2, 2001      4647
# 561              Banterra Bank of Marion   December 14, 2000      4646
# 562                   Bank of the Orient    October 13, 2000      4645
#
# [563 rows x 7 columns]

# %%
pd.set_option('display.max_rows',563)
pd.set_option('display.max_columns',7)

# %%
df[0].head()
# Out:
#                       Bank NameBank           CityCity StateSt  CertCert  \
# 0                 Almena State Bank             Almena      KS     15426
# 1        First City Bank of Florida  Fort Walton Beach      FL     16748
# 2              The First State Bank      Barboursville      WV     14361
# 3                Ericson State Bank            Ericson      NE     18265
# 4  City National Bank of New Jersey             Newark      NJ     21111
#
#       Acquiring InstitutionAI Closing DateClosing  FundFund
# 0                 Equity Bank    October 23, 2020     10538
# 1   United Fidelity Bank, fsb    October 16, 2020     10537
# 2              MVB Bank, Inc.       April 3, 2020     10536
# 3  Farmers and Merchants Bank   February 14, 2020     10535
# 4             Industrial Bank    November 1, 2019     10534

# %%
df = df[0]

# %%
df.columns
# Out:
# Index(['Bank NameBank', 'CityCity', 'StateSt', 'CertCert',
#        'Acquiring InstitutionAI', 'Closing DateClosing', 'FundFund'],
#       dtype='object')

# %%
new_names = ['Bank_Name', 'City', 'State', 'Cert',
       'InstitutionAI', 'Closing_Date', 'Fund']

# %%
df.columns = new_names

# %%
df.head(2)
# Out:
#                     Bank_Name               City State   Cert  \
# 0           Almena State Bank             Almena    KS  15426
# 1  First City Bank of Florida  Fort Walton Beach    FL  16748
#
#                InstitutionAI      Closing_Date   Fund
# 0                Equity Bank  October 23, 2020  10538
# 1  United Fidelity Bank, fsb  October 16, 2020  10537

# %%
df['Closing_Date'].dtypes
# Out:
# dtype('O')

# %%
df['date'] = pd.to_datetime(df['Closing_Date'])

# %%
pd.set_option('display.max_columns',None)

# %%
df.drop('date', axis=1, inplace=True)

# %%
df.head()
# Out:
#                           Bank_Name               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# FL
# VA
# IL
# OH
# GA
# GA
# GA
# FL
# CA
# FL
# FL
# CA
# MO
# MN
# MI
# GA
# TX
# TX
# TX
# IL
# CA
# CA
# CA
# IL
# AZ
# IL
# MN
# WI
# FL
# FL
# GA
# FL
# CA
# CO
# MN
# MI
# GA
# KY
# IN
# WA
# MN
# IL
# AZ
# IL
# IA
# IL
# MO
# CA
# MN
# MD
# TX
# AL
# GA
# GA
# NV
# AZ
# AZ
# AL
# PA
# OR
# FL
# FL
# IL
# NJ
# OH
# FL
# OK
# GA
# GA
# GA
# GA
# GA
# GA
# NY
# CA
# CA
# SD
# GA
# WY
# IL
# TX
# IL
# IL
# IL
# IL
# IL
# CA
# CA
# MN
# GA
# GA
# KS
# NC
# GA
# IL
# IL
# IL
# FL
# WA
# UT
# NJ
# GA
# ID
# CA
# MI
# GA
# NV
# MO
# CO
# NC
# GA
# KS
# CO
# GA
# GA
# NV
# IL
# OR
# OR
# IL
# FL
# NE
# CA
# CA
# GA
# FL
# MD
# UT
# CA
# WA
# IL
# TX
# GA
# GA
# CA
# CA
# GA
# CA
# TX
# FL
# GA
# IL
# MI
# NV
# WV
# NV
# GA
# KS
# FL
# CA
# NV
# CA
# MN
# AR
# MO
# MO
# OH
# GA
# PA
# UT
# NY
# FL
# NJ
# PA
# WI
# CA
# LA
# TN
# GA
# IL
# CT
# MI
# FL
# AZ
# OH
# TX
# FL
# AR
# IL
# OH
# NH
# IL
# HI

# %%
# Dropping the Closing_date cpolumn
df.drop('Closing_Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#                           Bank_Name               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#                 InstitutionAI   Fund       date
# 0                 Equity Bank  10538 2020-10-23
# 1   United Fidelity Bank, fsb  10537 2020-10-16
# 2              MVB Bank, Inc.  10536 2020-04-03
# 3  Farmers and Merchants Bank  10535 2020-02-14
# 4             Industrial Bank  10534 2019-11-01

# %%
df['date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
#df['date'] =df['date'].apply(lambda x: x.split('-'))

# %%
# Now, lets convert the datetime object to a string
df['date'] = df['date'].astype('string')

# %%
df['date'].dtypes
# Out:
# string[python]

# %%
df['Year'] =df['date'].apply(lambda x: x.split('-')[0])
df['Month'] =df['date'].apply(lambda x: x.split('-')[1])
df['Day'] =df['date'].apply(lambda x: x.split('-')[2])

# %%
df.head()
# Out:
#                           Bank_Name               City State  ...  Year Month  \
# 0                 Almena State Bank             Almena    KS  ...  2020    10
# 1        First City Bank of Florida  Fort Walton Beach    FL  ...  2020    10
# 2              The First State Bank      Barboursville    WV  ...  2020    04
# 3                Ericson State Bank            Ericson    NE  ...  2020    02
# 4  City National Bank of New Jersey             Newark    NJ  ...  2019    11
#
#    Day
# 0   23
# 1   16
# 2   03
# 3   14
# 4   01
#
# [5 rows x 10 columns]

# %%
df.isna().sum()

# %%
for col in df.select_dtypes('object'):
    print(f'{col:-<30} {df[col].unique()}')

# %%
import matplotlib.pyplot as plt

# %%
for col in df.select_dtypes('object'):
    plt.figure(figsize=(12,8))
    df[col].value_counts().plot.pie()

# %% [markdown]
# ____

# %% [markdown]
# _____
# _____
# # SQL (Optional)
#
# * Note: If you are completely unfamiliar with SQL you can check out my other course: "Complete SQL Bootcamp" to learn SQL.

# %% [markdown]
# The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df

# %% [markdown]
# # Great Job!
